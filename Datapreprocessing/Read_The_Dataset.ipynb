# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
dataset_train=pd.read_csv('PM_train.csv',sep=' ',header=None).drop([26,27],axis=1)
col_names = ['id','cycle','setting1','setting2','setting3','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10','s11','s12','s13','s14','s15','s16','s17','s18','s19','s20','s21']
dataset_train.columns=col_names
print("Shape of Train dataset: ",dataset_train.shape)
dataset_train.head()
# Out:
# Shape of Train dataset:  (12314, 26)
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...     s12      s13      s14     s15   s16    s17     s18    s19  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392.0  2388.0  100.0
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392.0  2388.0  100.0
# 2  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03  390.0  2388.0  100.0
# 3  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03  392.0  2388.0  100.0
# 4  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03  393.0  2388.0  100.0
#
#      s20      s21
# 0  39.06  23.4190
# 1  39.00  23.4236
# 2  38.95  23.3442
# 3  38.88  23.3739
# 4  38.90  23.4044
#
# [5 rows x 26 columns]

# %%
dataset_test=pd.read_csv('PM_test.csv',sep=' ',header=None).drop([26,27],axis=1)
dataset_test.columns=col_names
print("Shape of Test dataset: ",dataset_train.shape)
dataset_train.head()
# Out:
# Shape of Test dataset:  (12314, 26)
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...     s12      s13      s14     s15   s16    s17     s18    s19  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392.0  2388.0  100.0
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392.0  2388.0  100.0
# 2  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03  390.0  2388.0  100.0
# 3  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03  392.0  2388.0  100.0
# 4  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03  393.0  2388.0  100.0
#
#      s20      s21
# 0  39.06  23.4190
# 1  39.00  23.4236
# 2  38.95  23.3442
# 3  38.88  23.3739
# 4  38.90  23.4044
#
# [5 rows x 26 columns]

# %%
pm_truth=pd.read_csv('PM_truth.csv',sep=' ',header=None).drop([1],axis=1)
pm_truth.columns=['more']
pm_truth['id']=pm_truth.index+1
pm_truth.head()
# Out:
#    more  id
# 0   112   1
# 1    98   2
# 2    69   3
# 3    82   4
# 4    91   5
